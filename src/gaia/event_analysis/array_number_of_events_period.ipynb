# %%
import numpy as np
import os
import pandas as pd
import struct
import matplotlib.pyplot as plt
from utils.event2d import event2d as event2d
from utils.helper import *

plt.style.use("MC.mplstyle")

# %%
fileName = "../Recordings/0812_period_numevents_5Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
ev_5hz = gaia4096_extractor(events)

fileName = "../Recordings/0812_period_numevents_5Hz_2.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
ev_5hz_2 = gaia4096_extractor(events)

# %%
plt.figure(figsize=(20,3))

plotty = select_event_in_timewindow(ev_5hz, t_start=1.4, t_stop=1.6)
plt.figure(figsize=(20,10))
for e in ev_5hz_2:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 5 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
plt.figure(figsize=(20,3))

plotty = select_event_in_timewindow(ev_50hz, t_start=0.75, t_stop=0.8)
plt.figure(figsize=(20,10))
for e in ev_5hz_2:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 500 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
plt.figure(figsize=(20,3))

fileName = "../Recordings/0812_period_numevents_5Hz_3.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
ev_5hz_3 = gaia4096_extractor(events)

plotty = select_event_in_timewindow(ev_5hz_3, t_start=0.888, t_stop=1.1)

ev = remove_ts_offset(plotty)
plt.figure(figsize=(20,10))
for e in plotty:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 500 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
numb_ev5Hz = len(plotty)

# %%
plt_ev = np.zeros((75,75))
for i in range(len(plotty)):
    plt_ev[plotty[i].x][plotty[i].y] += 1
    
plt.imshow(plt_ev)
plt.colorbar()

# %%
plt_ev.mean()
# Out:
# 0.8787555555555555

# %%
plt.figure(figsize=(20,3))

fileName = "../Recordings/0812_period_numevents_50Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
ev_50hz_2 = gaia4096_extractor(events)

plotty = select_event_in_timewindow(ev_50hz_2, t_start=1.515, t_stop=1.535)
plt.figure(figsize=(20,10))
for e in plotty:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 50 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
numb_ev50Hz = len(plotty)

# %%
numb_ev50Hz
# Out:
# 1382

# %%
plt.figure(figsize=(20,3))

fileName = "../Recordings/0812_period_numevents_500Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
ev_500hz = gaia4096_extractor(events)

plotty = select_event_in_timewindow(ev_500hz, t_start=4.899, t_stop=4.901)
plt.figure(figsize=(20,10))
for e in plotty:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 500 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
plt.xlim([4.899, 4.901])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (4.899, 4.901)

# %%
1/500
# Out:
# 0.002

# %%
numb_ev500Hz = len(plotty)

# %%
num_ev=[numb_ev5Hz , numb_ev50Hz, numb_ev500Hz]
rates = [5,50,500]
plt.semilogx( rates, num_ev ,'x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/matteo/Repositories/gaia-gui-interface/src/gaia/event_analysis/array_number_of_events_period.ipynb Cell 15' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/matteo/Repositories/gaia-gui-interface/src/gaia/event_analysis/array_number_of_events_period.ipynb#ch0000012?line=0'>1</a> num_ev=[numb_ev5Hz , numb_ev50Hz, numb_ev500Hz]
#       <a href='vscode-notebook-cell:/Users/matteo/Repositories/gaia-gui-interface/src/gaia/event_analysis/array_number_of_events_period.ipynb#ch0000012?line=1'>2</a> rates = [5,50,500]
# ----> <a href='vscode-notebook-cell:/Users/matteo/Repositories/gaia-gui-interface/src/gaia/event_analysis/array_number_of_events_period.ipynb#ch0000012?line=2'>3</a> plt.semilogx( rates, num_ev ,'x.')
#
# ...

# %%
num_ev
# Out:
# [4943, 1123, 1628]
