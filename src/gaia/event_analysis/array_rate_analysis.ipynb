# %%
import numpy as np
import os
import pandas as pd
import struct
import matplotlib.pyplot as plt
from utils.event2d import event2d as event2d
from utils.helper import *

plt.style.use("MC.mplstyle")

# %%
fileName = "../Recordings/array_sweep_100Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_100Hz = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_500Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_500Hz = gaia4096_extractor(events)

# %%
\

# %%
fileName = "../Recordings/array_sweep_1kHz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_1kHz = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_5kHz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_5kHz = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_1Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_1Hz_sine = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_5Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_5Hz_sine = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_10Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_10Hz_sine = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_50Hz.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_50Hz_sine = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_10Hz_square.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_10Hz_square = gaia4096_extractor(events)

# %%
fileName = "../Recordings/array_sweep_1Hz_square.dat"
events = read_dat_file(fileName)
ev = remove_ts_offset(events)
gaia4096_1Hz_square = gaia4096_extractor(events)

# %%
rate_100 = get_event_rate(gaia4096_100Hz)
rate_500 = get_event_rate(gaia4096_500Hz)
rate_1k = get_event_rate(gaia4096_1kHz)
rate_5k = get_event_rate(gaia4096_5kHz)
rate_1 = get_event_rate(gaia4096_1Hz_sine)
rate_5 = get_event_rate(gaia4096_5Hz_sine)
rate_10 = get_event_rate(gaia4096_10Hz_sine)
rate_50 = get_event_rate(gaia4096_50Hz_sine)

# %%
print(rate_100,rate_500, rate_1k,rate_5k,rate_1,rate_5,rate_10,rate_50)
# Out:
# 234311.4033603651 242554.77252025504 241189.27313145215 239066.72088767533 3182.512277266705 58321.93029548332 112915.39665540817 217359.27117503574

# %%
plotty = select_event_in_timewindow(gaia4096_100Hz, t_start=1., t_stop=1.03)
len(plotty)
# Out:
# 7471

# %%
plotty = select_event_in_timewindow(gaia4096_50Hz_sine, t_start=0, t_stop=0.2)
plt.figure(figsize=(20,10))
for e in plotty:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 100 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
plotty = select_event_in_timewindow(gaia4096_10Hz_sine, t_start=0, t_stop=0.2)
plt.figure(figsize=(20,10))
for e in plotty:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 10 Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
plotty = select_event_in_timewindow(gaia4096_50Hz_sine, t_start=1., t_stop=1.08)
plt.figure(figsize=(20,10))
for e in plotty:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
#plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 5Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time [s]')

# %%
plt.figure(figsize=(20,10))
for e in gaia4096_1Hz[2000:10000]:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 1Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# Text(0.5, 0, 'Time [s]')
# /Users/matteo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/matteo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20,10))
for e in gaia4096_50Hz[2000:20000]:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 50Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# Text(0.5, 0, 'Time [s]')
# /Users/matteo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/matteo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20,10))
for e in gaia4096_10Hz[2000:20000]:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 10Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# Text(0.5, 0, 'Time [s]')

# %%
plt.figure(figsize=(20,10))
for e in gaia4096_10Hz_square[2000:20000]:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 10Hz")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# Text(0.5, 0, 'Time [s]')
# /Users/matteo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20,10))
for e in gaia4096_1Hz_square[20000:40000]:
    if e.p ==0 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.')
    if e.p ==1 :
        plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.')

plt.plot(e.ts*1e-5, e.x + 64*e.y , 'g.',label = "ON")
plt.plot(e.ts*1e-5, e.x + 64*e.y , 'r.',label = "OFF")

        
plt.legend(prop={'size': 30})
plt.title("Raster plot gaia4096 1Hz square")
plt.ylabel("Channel ID")
plt.xlabel("Time [s]")
# Out:
# Text(0.5, 0, 'Time [s]')
# /Users/matteo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
